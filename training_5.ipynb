# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import cifar
# Out:
# Using gpu device 0: GeForce GTX 580 (CNMeM is enabled)

# %%
results = cifar.train_cifar(150, 500)
# Out:
# Loading data...
# Starting training...
# Epoch 1 of 150 took 90.791s
#   training loss:		2.288814
#   validation loss:		2.249804
#   validation accuracy:		17.37 %
# Epoch 2 of 150 took 90.266s
#   training loss:		2.177650
#   validation loss:		2.110047
#   validation accuracy:		21.26 %
# Epoch 3 of 150 took 90.180s
#   training loss:		2.064626
#   validation loss:		2.022914
#   validation accuracy:		22.17 %
# Epoch 4 of 150 took 90.246s
#   training loss:		1.995447
#   validation loss:		1.945791
#   validation accuracy:		26.29 %
# Epoch 5 of 150 took 90.079s
#   training loss:		1.927460
#   validation loss:		1.966637
#   validation accuracy:		29.36 %
# Epoch 6 of 150 took 90.149s
#   training loss:		1.838536
#   validation loss:		1.799032
#   validation accuracy:		34.02 %
# Epoch 7 of 150 took 90.337s
#   training loss:		1.769497
#   validation loss:		1.726972
#   validation accuracy:		35.92 %
# Epoch 8 of 150 took 90.057s
#   training loss:		1.691516
#   validation loss:		1.654358
# ...

# %%
title("Validation accuracy")
xlabel("epoch")
ylabel("accuracy [%]")
plot(array(results[0])/results[1]*100)
