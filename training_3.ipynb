# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import cifar
# Out:
# Using gpu device 0: GeForce GTX 580 (CNMeM is enabled)

# %%
results = cifar.train_cifar(500)
# Out:
# Loading data...
# Starting training...
# Epoch 1 of 500 took 13.801s
#   training loss:		2.275102
#   validation loss:		2.152514
#   validation accuracy:		21.40 %
# Epoch 2 of 500 took 13.798s
#   training loss:		2.097258
#   validation loss:		1.955090
#   validation accuracy:		27.09 %
# Epoch 3 of 500 took 13.805s
#   training loss:		1.925495
#   validation loss:		1.772178
#   validation accuracy:		34.60 %
# Epoch 4 of 500 took 13.759s
#   training loss:		1.804790
#   validation loss:		1.652216
#   validation accuracy:		39.41 %
# Epoch 5 of 500 took 13.731s
#   training loss:		1.699281
#   validation loss:		1.635170
#   validation accuracy:		40.78 %
# Epoch 6 of 500 took 13.730s
#   training loss:		1.622209
#   validation loss:		1.494983
#   validation accuracy:		45.65 %
# Epoch 7 of 500 took 13.728s
#   training loss:		1.559093
#   validation loss:		1.428107
#   validation accuracy:		48.19 %
# Epoch 8 of 500 took 13.726s
#   training loss:		1.520581
#   validation loss:		1.396207
# ...

# %%
title("Validation accuracy")
xlabel("epoch")
ylabel("accuracy [%]")
plot(array(results[0])/results[1]*100)
