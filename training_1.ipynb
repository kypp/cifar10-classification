# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import cifar

# %%
results = cifar.train_cifar(100)
# Out:
# Loading data...
# Starting training...
# Epoch 1 of 100 took 8.663s
#   training loss:		2.296590
#   validation loss:		2.267339
#   validation accuracy:		16.02 %
# Epoch 2 of 100 took 8.660s
#   training loss:		2.181237
#   validation loss:		2.093579
#   validation accuracy:		22.10 %
# Epoch 3 of 100 took 8.663s
#   training loss:		2.077656
#   validation loss:		1.989734
#   validation accuracy:		26.23 %
# Epoch 4 of 100 took 8.663s
#   training loss:		1.979585
#   validation loss:		1.880629
#   validation accuracy:		29.46 %
# Epoch 5 of 100 took 8.659s
#   training loss:		1.889153
#   validation loss:		1.815854
#   validation accuracy:		30.29 %
# Epoch 6 of 100 took 8.662s
#   training loss:		1.835539
#   validation loss:		1.786439
#   validation accuracy:		31.81 %
# Epoch 7 of 100 took 8.662s
#   training loss:		1.785849
#   validation loss:		1.819187
#   validation accuracy:		31.04 %
# Epoch 8 of 100 took 8.659s
#   training loss:		1.745825
#   validation loss:		1.637362
# ...

# %%
title("Validation accuracy")
xlabel("epoch")
ylabel("accuracy [%]")
plot(array(results[0])/results[1]*100)
