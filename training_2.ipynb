# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import cifar
# Out:
# Using gpu device 0: GeForce GTX 580 (CNMeM is enabled)

# %%
results = cifar.train_cifar(100)
# Out:
# Loading data...
# Starting training...
# Epoch 1 of 100 took 11.001s
#   training loss:		2.281593
#   validation loss:		2.195498
#   validation accuracy:		16.41 %
# Epoch 2 of 100 took 10.994s
#   training loss:		2.142727
#   validation loss:		2.060826
#   validation accuracy:		23.93 %
# Epoch 3 of 100 took 10.999s
#   training loss:		2.052216
#   validation loss:		1.950337
#   validation accuracy:		26.99 %
# Epoch 4 of 100 took 10.996s
#   training loss:		1.945970
#   validation loss:		2.105327
#   validation accuracy:		20.70 %
# Epoch 5 of 100 took 11.000s
#   training loss:		1.874416
#   validation loss:		1.748449
#   validation accuracy:		36.45 %
# Epoch 6 of 100 took 11.002s
#   training loss:		1.770246
#   validation loss:		1.809885
#   validation accuracy:		35.77 %
# Epoch 7 of 100 took 11.003s
#   training loss:		1.699706
#   validation loss:		1.544600
#   validation accuracy:		43.57 %
# Epoch 8 of 100 took 11.000s
#   training loss:		1.633335
#   validation loss:		1.530560
# ...

# %%
title("Validation accuracy")
xlabel("epoch")
ylabel("accuracy [%]")
plot(array(results[0])/results[1]*100)
